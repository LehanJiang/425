# %%
from google.colab import drive
import pandas as pd
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive/', force_remount =True)
# Out:
# Mounted at /content/gdrive/

# %%
df = pd.read_excel('/content/gdrive/MyDrive/ECON441B/BYD.xls')
df
# Out:
#            Date    Dret  IdxDRet
# 0    2017-01-03  0.0030   0.0097
# 1    2017-01-04  0.0195   0.0078
# 2    2017-01-05 -0.0073  -0.0002
# 3    2017-01-06 -0.0125  -0.0060
# 4    2017-01-09  0.0022   0.0048
# ...         ...     ...      ...
# 1212 2021-12-27 -0.0110  -0.0004
# 1213 2021-12-28  0.0143   0.0074
# 1214 2021-12-29 -0.0068  -0.0146
# 1215 2021-12-30 -0.0070   0.0078
# 1216 2021-12-31  0.0037   0.0038
#
# [1217 rows x 3 columns]

# %%
df.set_index('Date',inplace = True)

# %%
plt.figure(figsize = (16,8))
plt.plot(df['Dret'])
plt.xlabel('Date')
plt.ylabel("Daily Return Rate")
plt.title("BYD Daily Return Rate")
plt.show()

# %% [markdown]
# The mean of BYD return rate is around 0, and BYD return rate is in range from -0.1 to 0.1.
